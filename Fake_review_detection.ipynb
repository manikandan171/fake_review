# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %% [markdown]
# ### Inserting fake and real dataset

# %%
df_fake = pd.read_csv("fake.csv")
df_true = pd.read_csv("True.csv")

# %%
df_fake.head(5)
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5       5    CG
# 1  Home_and_Kitchen_5       5    CG
# 2  Home_and_Kitchen_5       5    CG
# 3  Home_and_Kitchen_5       1    CG
# 4  Home_and_Kitchen_5       5    CG
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...
# 3  Missing information on how to use it, but it i...
# 4  Very nice set. Good quality. We have had the s...

# %%
df_true.head(5)
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5       5    OR
# 1  Home_and_Kitchen_5       5    OR
# 2  Home_and_Kitchen_5       5    OR
# 3  Home_and_Kitchen_5       5    OR
# 4  Home_and_Kitchen_5       5    OR
#
#                                                text_
# 0  These are just perfect, exactly what I was loo...
# 1  Such a great purchase can't beat it for the price
# 2  What can you say--- cheap and it works as inte...
# 3  These are so nice, sturdy, like the color choi...
# 4      It is nice bowl and have had a fast shipping!

# %% [markdown]
# Inserting a column called "class" for fake and real news dataset to categories fake and true news.

# %%
df_fake["class"] = 0
df_true["class"] = 1

# %% [markdown]
# Removing last 10 rows from both the dataset, for manual testing

# %%
df_fake.shape, df_true.shape
# Out:
# ((20216, 5), (20216, 5))

# %%
df_fake_manual_testing = df_fake.tail(10)
for i in range(20200, 20205, -1):
    if i in df_fake.index:
        df_fake.drop([i], axis=0, inplace=True)
    else:
        print(f"Index {i} not found in DataFrame")

df_true_manual_testing = df_true.tail(10)
for i in range(20200, 20205, -1):
    if i in df_true.index:
        df_true.drop([i], axis=0, inplace=True)
    else:
        print(f"Index {i} not found in DataFrame")

# %%
df_fake.shape, df_true.shape
# Out:
# ((20216, 5), (20216, 5))

# %% [markdown]
# Merging the manual testing dataframe in single dataset and save it in a csv file

# %%
df_fake_manual_testing["class"] = 0
df_true_manual_testing["class"] = 1
# Out:
# C:\Users\Manikandan\AppData\Local\Temp\ipykernel_6716\860779283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fake_manual_testing["class"] = 0
# C:\Users\Manikandan\AppData\Local\Temp\ipykernel_6716\860779283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_true_manual_testing["class"] = 1

# %%
df_fake_manual_testing.head(10)
# Out:
#                            category  rating label  \
# 20206  Clothing_Shoes_and_Jewelry_5       5    CG
# 20207  Clothing_Shoes_and_Jewelry_5       4    CG
# 20208  Clothing_Shoes_and_Jewelry_5       3    CG
# 20209  Clothing_Shoes_and_Jewelry_5       2    CG
# 20210  Clothing_Shoes_and_Jewelry_5       5    CG
# 20211  Clothing_Shoes_and_Jewelry_5       4    CG
# 20212  Clothing_Shoes_and_Jewelry_5       3    CG
# 20213  Clothing_Shoes_and_Jewelry_5       5    CG
# 20214  Clothing_Shoes_and_Jewelry_5       5    CG
# 20215  Clothing_Shoes_and_Jewelry_5       1    CG
#
#                                                    text_  class
# 20206  OMG, First reason why I chose this style is be...      0
# 20207  First off I returned this pair. The quality is...      0
# 20208  When I saw this ring, I thought it was very be...      0
# 20209  This bag weighs exactly 10pounds (I wear an XL...      0
# 20210  I just bought these locally and they are the b...      0
# 20211  I wore this from 4pm to 9pm and it was perfect...      0
# 20212  I kind of feel giving it a 3 star because it's...      0
# 20213  Overall, I love this hat!\n\nSize/Color:  9.5/...      0
# 20214  I wasn't sure exactly what it would be. It is ...      0
# 20215  I liked nothing about this dress. The only rea...      0

# %%
df_true_manual_testing.head(10)
# Out:
#                            category  rating label  \
# 20206  Clothing_Shoes_and_Jewelry_5       5    OR
# 20207  Clothing_Shoes_and_Jewelry_5       5    OR
# 20208  Clothing_Shoes_and_Jewelry_5       5    OR
# 20209  Clothing_Shoes_and_Jewelry_5       5    OR
# 20210  Clothing_Shoes_and_Jewelry_5       2    OR
# 20211  Clothing_Shoes_and_Jewelry_5       4    OR
# 20212  Clothing_Shoes_and_Jewelry_5       5    OR
# 20213  Clothing_Shoes_and_Jewelry_5       4    OR
# 20214  Clothing_Shoes_and_Jewelry_5       2    OR
# 20215  Clothing_Shoes_and_Jewelry_5       5    OR
#
#                                                    text_  class
# 20206  The cold damp fog tries to grab at my ankles a...      1
# 20207  I'd consider myself an advanced non-profession...      1
# 20208  I cannot thank my boss enough for recommending...      1
# 20209  Sometimes it is so hard to find a loose comfor...      1
# 20210  I'm a 36B, which means that I don't need any h...      1
# 20211  This is a classy looking watch.  I don't get m...      1
# 20212  The stated dimensions on the description are o...      1
# 20213  I had read some reviews saying that this bra r...      1
# 20214  You can wear the hood by itself, wear it with ...      1
# 20215  I work in the wedding industry and have to wor...      1

# %%
df_manual_testing = pd.concat([df_fake_manual_testing,df_true_manual_testing], axis = 0)
df_manual_testing.to_csv("manual_testing.csv")

# %% [markdown]
# Merging the main fake and true dataframe

# %%
df_marge = pd.concat([df_fake, df_true], axis =0 )
df_marge.head(10)
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5       5    CG
# 1  Home_and_Kitchen_5       5    CG
# 2  Home_and_Kitchen_5       5    CG
# 3  Home_and_Kitchen_5       1    CG
# 4  Home_and_Kitchen_5       5    CG
# 5  Home_and_Kitchen_5       3    CG
# 6  Home_and_Kitchen_5       5    CG
# 7  Home_and_Kitchen_5       3    CG
# 8  Home_and_Kitchen_5       5    CG
# 9  Home_and_Kitchen_5       5    CG
#
#                                                text_  class
# 0  Love this!  Well made, sturdy, and very comfor...      0
# 1  love it, a great upgrade from the original.  I...      0
# 2  This pillow saved my back. I love the look and...      0
# 3  Missing information on how to use it, but it i...      0
# 4  Very nice set. Good quality. We have had the s...      0
# 5       I WANTED DIFFERENT FLAVORS BUT THEY ARE NOT.      0
# 6  They are the perfect touch for me and the only...      0
# 7  These done fit well and look great.  I love th...      0
# 8  Great big numbers & easy to read, the only thi...      0
# 9  My son loves this comforter and it is very wel...      0

# %%
df_marge.columns
# Out:
# Index(['category', 'rating', 'label', 'text_', 'class'], dtype='object')

# %% [markdown]
# #### "title",  "subject" and "date" columns is not required for detecting the fake news, so I am going to drop the columns.

# %%
df = df_marge.drop(["category","rating","label"], axis = 1)

# %%
df.isnull().sum()
# Out:
# text_    0
# class    0
# dtype: int64

# %% [markdown]
# #### Randomly shuffling the dataframe

# %%
df = df.sample(frac = 1)

# %%
df.head()
# Out:
#                                                    text_  class
# 7014   Snow White, the queen.. good twist and creativ...      1
# 17879  My 9 yr. old requested this for Christmas.  Wh...      1
# 5186   It is okay due to its low price point. It does...      1
# 7249   We laughed so hard, it was a complete surprise...      1
# 15441  Compelling story that weaves some Chinese folk...      1

# %%
df.reset_index(inplace = True)
df.drop(["index"], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['text_', 'class'], dtype='object')

# %%
df.head()
# Out:
#                                                text_  class
# 0  Snow White, the queen.. good twist and creativ...      1
# 1  My 9 yr. old requested this for Christmas.  Wh...      1
# 2  It is okay due to its low price point. It does...      1
# 3  We laughed so hard, it was a complete surprise...      1
# 4  Compelling story that weaves some Chinese folk...      1

# %% [markdown]
# #### Creating a function to convert the text in lowercase, remove the extra space, special chr., ulr and links.

# %%
import re
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text

# %%
df["text_"] = df["text_"].apply(wordopt)

# %% [markdown]
# #### Defining dependent and independent variable as x and y

# %%
x = df["text_"]
y = df["class"]

# %% [markdown]
# #### Splitting the dataset into training set and testing set.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %% [markdown]
# #### Convert text to vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9010684606252474

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      5071
#            1       0.89      0.92      0.90      5037
#
#     accuracy                           0.90     10108
#    macro avg       0.90      0.90      0.90     10108
# weighted avg       0.90      0.90      0.90     10108

# %% [markdown]
# ###  Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test, y_test)
# Out:
# 0.7754254056193114

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      5071
#            1       0.78      0.76      0.77      5037
#
#     accuracy                           0.78     10108
#    macro avg       0.78      0.78      0.78     10108
# weighted avg       0.78      0.78      0.78     10108

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBC=GradientBoostingClassifier(random_state=0)
GBC.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
GBC.score(xv_test, y_test)
# Out:
# 0.8477443609022557

# %%
pred_GBC=GBC.predict(xv_test)

# %%
print(classification_report(y_test, pred_GBC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      5071
#            1       0.84      0.86      0.85      5037
#
#     accuracy                           0.85     10108
#    macro avg       0.85      0.85      0.85     10108
# weighted avg       0.85      0.85      0.85     10108

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier(random_state=0)
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rfc = RFC.predict(xv_test)

# %%
RFC.score(xv_test, y_test)
# Out:
# 0.8881084289671547

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      5071
#            1       0.91      0.86      0.88      5037
#
#     accuracy                           0.89     10108
#    macro avg       0.89      0.89      0.89     10108
# weighted avg       0.89      0.89      0.89     10108

# %% [markdown]
# # Testing With Manual Entry

# %%
def output_lable(n):
    if n == 0:
        return "Fake Review"
    elif n == 1:
        return "Not A Fake Fake Review"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt) 
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GBC = GBC.predict(new_xv_test)
    pred_RFC = RFC.predict(new_xv_test)

    return print("\n\nLinear Regression Prediction: {} \nDecision Tree  Prediction: {} \nGradient Boosting  Prediction: {} \nRandom Forest Classifier Prediction: {}".format(output_lable(pred_LR[0]), 
                                                                                                              output_lable(pred_DT[0]), 
                                                                                                              output_lable(pred_GBC[0]), 
                                                                                                              output_lable(pred_RFC[0])))

# %%
news = str(input())
manual_testing(news)
